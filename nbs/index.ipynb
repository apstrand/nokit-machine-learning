# %%
#| hide
from nokit_machine_learning.core import *

# %% [markdown]
# # nokit-machine-learning
#
# > Machine learning from scratch

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nokit_machine_learning in Development mode

# %% [markdown]
# ```sh
# # make sure nokit_machine_learning package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nokit_machine_learning
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/apstrand/nokit-machine-learning.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c apstrand nokit_machine_learning
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nokit_machine_learning
# ```
#
#
# [repo]: https://github.com/apstrand/nokit-machine-learning
# [docs]: https://apstrand.github.io/nokit-machine-learning/
# [pypi]: https://pypi.org/project/nokit-machine-learning/
# [conda]: https://anaconda.org/apstrand/nokit-machine-learning

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/apstrand/nokit-machine-learning
# [docs]: https://apstrand.github.io/nokit-machine-learning/
# [pypi]: https://pypi.org/project/nokit-machine-learning/
# [conda]: https://anaconda.org/apstrand/nokit-machine-learning

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
